# %% [markdown]
# ### LLM Call
#
# > Normal LLM use

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
chat_completion = client.chat.completions.create(
    messages=[
        {'role': 'user',
         'content':"Tell me a fun fact/"}
    ],
    model="gpt-5-mini"
)
print(chat_completion.choices[0].message.content)
# Out:
# Fun fact: wombats produce cube-shaped poop. Their intestines gradually shape the feces into little cubes so it stacks on rocks and logs without rolling away — handy for marking territory and communicating with other wombats.

# %% [markdown]
# > Langchain

# %%
from langchain_openai import ChatOpenAI

llm_openaai = ChatOpenAI(model='gpt-5-mini',
                         temperature=0)

llm_openaai.invoke("Tell me a Fun fact.").content
# Out:
# 'Fun fact: Botanically, bananas are berries — but strawberries aren’t. \n\nWhy: a berry is a fruit that develops from a single ovary and has fleshy tissue all the way through; bananas fit that definition, whereas strawberries are “accessory fruits” with the seeds (the little dots) on the outside. Want another fun fact?'

# %%
from langchain.chat_models import init_chat_model

llm_openai = init_chat_model(model='gpt-5-mini')
llm_openai.invoke("hey, How are you?")
# Out:
# AIMessage(content="I'm an AI, so I don't have feelings, but I'm here and ready to help. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 12, 'total_tokens': 46, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EGg2R2wPcO0zsZYs06oRrNFY2NUXx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a037db-ce8f-7183-9741-41075cefbd21-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 34, 'total_tokens': 46, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_
# ...

# %% [markdown]
#                                     (User Message)
#                             ------------------------------->
#                 **Person**                                     **AI Models**
#                             <--------------------------------
#                                         (AI Message)
#
#
# **WE can only control the user messages and not the the AI Messages, System messages is for LLMs but we can control it**, like we can say *talk to me nicely* etc...
